# %% [markdown]
# <a href="https://colab.research.google.com/github/jamunozlab/introductory_mechanics_spring_2026/blob/main/Phys_2320_workshop_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# ## Proportionality constants
#
# Many quantities are proportional, for example, your grade on a course is proportional to the time you spend preparing for that course. This is written as:
#
# .
#
# grade in course $\propto$ time spent preparing for course
#
# .
#
# where the symbol $\propto$, not to be confused with the Greek letter $\alpha$, is read *is proportional to*. Another common one is:
#
# .
#
# money $\propto$ time.
#
# .
#
# The proportionality constant is what makes one quantity *equal* to another. For example, if $p$ is how experienced your are at learning, grade in course $= p\, \times\,$ time spent preparing for course. Of course, $p$ might be affected by many factors. For example, if you like the material, you might not need to spend as much time because it would be easier to learn and hence get a good grade. Or perhaps it is a 'heavy' course and it requieres a lot of time to learn everything right.
#
# .
#
# In this course we have seen so far that to get, e.g., from velocity to acceleration you take the derivative of the velocity with respect to time. To get from the acceleration to the velocity you integrate. The relationship we will learn now is computationally simpler, although the philosophical questions are equally enjoyable. The relationship is:
#
# .
#
# force $\propto$ acceleration
#
# .
#
# The proportionality constant is what we call the *mass*, so $F = ma$, where $F$ is the force and $a$ is the acceleration. Mass is a complicated quantity in physics, and in fact the kilogram was the last unit in the International System to be defined in terms of fundamental quantities (in 2019). Nevertheless, for this course, we adopt a simple definition: the mass is the proportionality constant between the force and the acceleration. If you need to apply more force to impart an object with the same acceleration as another one, the former is more *massive* than the latter. From this simple definition, we can derive some powerful conclusions, which are true in classical mechanics:
#
#   1. Force and accelaration are the same thing, they only differ by their constant of proportionality.
#
#   2. You can only accelerate, or exert a force on, objects that have mass.

# %% [markdown]
# # Instructions
#
# 1. Evaluate the cells below, in some cases you might need to complete the code.
#
# 2. Complete the exercises.
#
# 3. Answer the questions in the space provided.
#
# NOTE: You do not need to know anything about pandas or lambda functions or even while loops right now. Your teaching assistant will demonstrate on the whiteboard what the code below is doing.

# %%
# Previously, you computed the following:

# %%
import pandas as pd #Import pandas package as "pd"

# %%
A = 4
B = -5
C = 3

time = 0
resolution = 0.01 # Δt
time_list = []    #Declare empty array  "time_list"
acceleration_list = [] # Declare empty array variable "acceleration list"
while time < 2.0: # WHILE LOOP, if "time" is LESS THAN 2, do this:
  time_list.append(time) # APPENED TIME LIST
  acceleration_list.append((lambda t: A*t**2 + B*t + C)(time)) # APPEND "acceleration_list" with the solution to the function "f(t) = 4t^2 + (-5)t+(3)
  time = time + resolution # INCREMENT TIME BY RESOLUTION

acceleration_vs_time = pd.Series(acceleration_list, index=time_list) # DEFINE A TWO COLUMN ARRAY VARIABLE CONSISTING OF ACCEL/TIME.
                                                                     # This two column arrray variable will allow  us to store and graph our data later using "pandas"
#// This "while loop" first computes the acceleration at time(t = 0) using the "lamba" function defined initially as: f(t)= 4(0)^2 + (-5)(0)+(3) => 3.
# Once that acceleration has been computed, that value is then appended to the array variable "acceleration_list",
# Finally the "time" variable is incremented by the resolution "0.1", just before the loop interates itselt again.

# This "while loop" iterates a total of 200 times from t=0 to t=1.99 until the LOOP EXIT CONDITION (while time < 2.0) is met. //

# %%
# Now, let's plot our acceleration/time data

acceleration_vs_time.plot(xlabel = "Time (s)", ylabel = "acceleration (m/s^2)", xlim=(0, 2), ylim=(0, acceleration_vs_time.max() + 1))

# %%
# Newton's second law states that F=ma, so F/m=a
# If the mass of the object being accelerated is 2 kg, the force neccessary
# to accelerate is the object is the acceleration from the plot above times the mass (2 kg)

# %%
A = 4
B = -5
C = 3

mass = 2 #kg (Notice this)
time = 0
resolution = 0.01
time_list = []
acceleration_list = []
force_list = [] # (Notice this)
while time < 2.0:
  time_list.append(time)
  acceleration_list.append((lambda x: A*x**2 + B*x + C)(time)) # This function propigates our acceleration list at each timestep
  force_list.append(mass * (lambda x: A*x**2 + B*x + C)(time)) # This function multiplies the mass times the acceleration at each timestep to solve for force required.
  time = time + resolution

force_vs_time = pd.Series(force_list, index=time_list) #store force and time data into two column array

# Upon inspection of this code cell, you'll find that this code accompllishes the same goal as the one above (propigate an acceleration list) with the added capability of
# computing for "Force Required" for each value of acceleration, and appending the results to the array variable "force_list" //

# %%
#Now, let's plot our Force/Time data

force_vs_time.plot(xlabel = "Time (s)", ylabel = "force (N)", xlim=(0, 2), ylim=(0, force_vs_time.max() + 1))

# %%
# Let's play around with the mass
# In the cell below, CHANGE THE VALUE OF THE MASS to 5 kg, 10 kg, and 50 kg
# Then answer the questions below

# %%
A = 4
B = -5
C = 3

mass = 5 #kg (CHANGE THIS)
time = 0
resolution = 0.01
time_list = []
acceleration_list = []
force_list = []
while time < 2.0:
  time_list.append(time)
  acceleration_list.append((lambda x: A*x**2 + B*x + C)(time))
  force_list.append(mass * (lambda x: A*x**2 + B*x + C)(time))
  time = time + resolution

force_vs_time = pd.Series(force_list, index=time_list)
force_vs_time.plot(xlabel = "Time (s)", ylabel = "force (N)", xlim=(0, 2), ylim=(0, force_vs_time.max() + 1))

# %% [markdown]
# # Exercise 4.1
#
# 4.1.1. What is the relationship between the plot of the acceleration vs. time and the plot of the force vs. time plot?
#
# 4.1.2. How does the shape of the force vs. time plot change when you change the mass, but keep the acceleration constant?
#
# 4.1.3. Do you need more or less force to accelerate a more massive object at the same rate as a less massive object?
#
# 4.1.4 What is the change in velocity if the acceleration is zero? What is the force you need to achieve this?
#
# 4.1.5 You do not need to provide a realistic answer to this question, but think about it. What is the total number of points you have for your quizzes in this course, and how many hours have you spent preparing for those quizzes? The units of the proportionality constant are points per hour. Do you think the proportionality constant for the exams will be lower, the same, or higer than for quizzes.

# %%
## 4.1.1 What is the relationship between the plot of the acceleration vs. time and the plot of the force vs. time plot?
##
## Answer:

# %%
## 4.1.2 How does the shape of the force vs. time plot change when you change the mass, but the acceleration profile remains the same?
##
## Answer:

# %%
## 4.1.3 Do you need more or less force to accelerate a more massive object at the same rate as a less massive object?
##
## Answer:

# %%
## 4.1.4 What is the change in velocity if the acceleration is zero? What is the force you need to achieve this?
##
## Answer:

# %%
## 4.1.5 In this course, will the proportionality constant for the exams will be lower, the same, or higher than for quizzes.
##
## Answer:
